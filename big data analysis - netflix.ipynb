# %%
import pandas as pd
df = pd.read_csv('Netflix Dataset.csv')

# %%
import seaborn as sns

# %% [markdown]
# Gathering Basic information about the dataset

# %%
df.shape #Number of rows and columns in the dataset
# Out:
# (7789, 11)

# %%
df.size #Number of values(elements) in the dataset
# Out:
# 85679

# %%
df.columns #Show each column name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.info() #Show index,columns, data type of each columns, memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# Find the number of duplicate records and remove them

# %%
df.shape
# Out:
# (7789, 11)

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# Identify the null values and remove them

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.dropna(inplace = True)

# %% [markdown]
# separte all the korean shows and movies

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
df[df['Country'].isin(['South Korea'])]
# Out:
#      Show_Id Category                               Title  \
# 27       s28    Movie                              #Alive
# 91       s92    Movie                            26 Years
# 284     s285  TV Show                     Abnormal Summit
# 606     s607    Movie          Asura: The City of Madness
# 1105   s1106  TV Show                  Bring It On, Ghost
# 1301   s1302  TV Show                  Cheese in the Trap
# 2244   s2245    Movie                           Forgotten
# 2461   s2462  TV Show                              Goedam
# 2733   s2734    Movie                        High Society
# 2929   s2930    Movie                             반드시 잡는다
# 2949   s2950    Movie            Illang: The Wolf Brigade
# 3191   s3192    Movie         Jo Pil-ho: The Dawning Rage
# 3806   s3807    Movie                         Lucid Dream
# 3896   s3897  TV Show                          Man to Man
# 3984   s3985    Movie                              Master
# ...

# %%
df[df['Country'].isin(['South Korea'])].shape
# Out:
# (43, 11)

# %% [markdown]
# For show House of cards, what is the Show ID and director

# %%
df[df['Title'].str.contains('House of Cards')][['Show_Id','Director']]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# In which year highest number of TV Shows and Movies were released?

# %%
df['date_N'] = pd.to_datetime(df['Release_Date'])

# %%
df['date_N'].dt.year.value_counts()
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: date_N, dtype: int64

# %%
df['date_N'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# How many TV shows and movies are there in the dataset?

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      4673
# TV Show     136
# Name: Category, dtype: int64

# %%
sns.countplot(x = 'Category', data = df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# Show all the movies released in 2000

# %%
df['Year'] = df['date_N'].dt.year

# %%
df[(df['Category'] == 'Movie') & (df['Year'] == 2020)]
# Out:
#      Show_Id Category                          Title  \
# 4         s5    Movie                             21
# 6         s7    Movie                            122
# 14       s15    Movie                           3022
# 27       s28    Movie                         #Alive
# 28       s29    Movie  #AnneFrank - Parallel Stories
# ...      ...      ...                            ...
# 7746   s7745    Movie    Yours Sincerely, Kanan Gill
# 7750   s7749    Movie                      الف مبروك
# 7762   s7761    Movie                      Zaki Chan
# 7783   s7782    Movie                           Zoom
# 7784   s7783    Movie                           Zozo
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7746                 Neville Shah
# 7750            Ahmed Nader Galal
# ...

# %% [markdown]
# Show top 10 directors who gave their TV Shows and Movies to Netflix

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# In how many movies TOM CRUISE is part of the cast

# %%
df[df['Cast'].str.contains('Tom Cruise') ]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     date_N  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [markdown]
# What are the different ratings defined by NETFLIX

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# How many TV Shows got R rating after 2018

# %%
df[(df['Category'] == 'TV Show')]
# Out:
#      Show_Id Category            Title            Director  \
# 5         s6  TV Show               46         Serdar Akar
# 132     s133  TV Show        7 (Seven)         Nizar Shafi
# 218     s219  TV Show  A Queen Is Born        Carla Barros
# 260     s261  TV Show         A.I.C.O.       Kazuya Murata
# 276     s277  TV Show     Abby Hatcher         Kyran Kelly
# ...      ...      ...              ...                 ...
# 7387   s7386  TV Show          Valeria       Inma Torrente
# 7402   s7401  TV Show           Velvet        Carlos Sedes
# 7494   s7493  TV Show   Watership Down          Noam Murro
# 7668   s7667  TV Show    World of Winx      Iginio Straffi
# 7723   s7722  TV Show              You  Lee Toland Krieger
#
#                                                    Cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...
# 218                       Gloria Groove, Alexia Twister
# ...

# %%
df[(df['Rating'] =='R')]
# Out:
#      Show_Id Category                       Title         Director  \
# 2         s3    Movie                       23:59     Gilbert Chan
# 7         s8    Movie                         187   Kevin Reynolds
# 14       s15    Movie                        3022       John Suits
# 17       s18    Movie                      22-Jul  Paul Greengrass
# 65       s66    Movie                     13 Sins     Daniel Stamm
# ...      ...      ...                         ...              ...
# 7712   s7711    Movie               Yes, God, Yes      Karen Maine
# 7738   s7737    Movie                 Young Adult    Jason Reitman
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
#
#                                                    Cast  \
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# ...

# %%
df[(df['Category'] == 'TV Show') & (df['Rating'] =='R') ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date_N, Year]
# Index: []

# %% [markdown]
# What is the maximum duration of a Movie/Show in Netflix

# %%
df[['Minutes','Unit']] = df['Duration'].str.split(' ',expand=True)

# %%
df.Minutes.max()
# Out:
# '99'

# %% [markdown]
# Which individual country has highest number of Movies/TV Shows

# %%
df.Country.value_counts().head(1)
# Out:
# United States    1654
# Name: Country, dtype: int64

# %%
df_tvshow = df[df['Category'] =='TV Show']

# %%
df_tvshow.Country.value_counts().head(1)
# Out:
# United States    27
# Name: Country, dtype: int64

# %% [markdown]
# Sort database by Year

# %%
df.sort_values('Year')
# Out:
#      Show_Id Category                              Title  \
# 7115   s7114    Movie               To and From New York
# 5766   s5766    Movie                           Splatter
# 3248   s3249    Movie            Just Another Love Story
# 3840   s3841    Movie        Mad Ron's Prevues from Hell
# 3221   s3222    Movie             Joseph: King of Dreams
# ...      ...      ...                                ...
# 1426   s1427    Movie  Cloudy with a Chance of Meatballs
# 1739   s1740    Movie        Dhobi Ghat (Mumbai Diaries)
# 7553   s7552    Movie          What Happened to Mr. Cha?
# 2479   s2480    Movie                          Good Hair
# 3237   s3238    Movie                      Julie & Julia
#
#                            Director  \
# 7115           Sorin Dan Mihalcescu
# 5766                      Joe Dante
# 3248                   Ole Bornedal
# 3840                     Jim Monaco
# 3221  Rob LaDuca, Robert C. Ramirez
# ...                             ...
# ...
